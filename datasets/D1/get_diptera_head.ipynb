# %% [markdown]
# # Algorithm for downloading images from iDigBio
# ###  (all images are verified by experts)
#
# All Diptera occurences from iDigBio are obtained and cleaned to preserve only those that have associated image of the frontal view (head) of the specimens.
#
# ### NOTE: to download the same images as in our study use this csv file
#
#     D1_list_of_filtered_images.csv
#
# ### Here is the walk trough how we acquired and filtered the images
#
# **Input**: multimedia.csv - a list of records from iDigBio obtained with query keywords ("hasImage":"true" and "order":"diptera")
#
# **Outputs**: images of frontal habitus sorted by family names
#
# Procedure:
#
# 	Step 1.
# 		collect:
# 			- images with keywords
# 				- 'dorsal'
# 				- 'habitus_dor', 'Habitus_dor'
# 				- '_D.', "_had"
# 			- images from institutions that provide mainly dorsal view
# 				- 'Denver Museum of Nature & Science'
# 	            - 'University of Tennessee at Chattanooga (UTC-UTCI)'
# 	            - 'United States National Museum, Entomology Collections (USNM-USNMENT)'
# 		skip:
# 			- images with keywords:
# 				- "lateral", "frontal", "ventral", 'anterior'
# 				- "head", 'antenna', "labels",
# 				- 'mesosoma', "genitalia"
# 				- "_L", "_F", "_V",
# 				- 'web', 'habitus_lat', 'Habitus_lat'
# 				- "hed", "hef", "hal", "hed" (head images)
#             - images from institutions that provided fossil images
# 		check:
# 			- from records that are not skipped or collected depict images from poorly represented families
# 	Step 2.
#     	- download images from families with N+ records
# 		- manually check all the images (to avoid drawings, images of labels, images where head is destroyed, etc.)
#
#
# We ended up with 11 families and 884 images.

# %%
import csv
import os
import urllib

# %%
with open('metadata/multimedia_raw.csv', 'rb') as csvfile:
    reader = csv.reader(csvfile)
    total_media = 0
    remained = []
    cleaned_list = []
    first_row = []
    #iterate over each row and count how many they are
    for row in reader:
        if first_row == []:
            first_row = row
    
        total_media +=1

        # and clean row 100 - some institutions provided only photos of labels with insects barelly visible or fossils
        # Arizona, Hawaii, Yale, Michigan, Texas
        
        if row[100] == 'University of Hawaii Insect Museum' or\
            row[100] == 'University of California Museum of Paleontology' or\
            row[100] == 'CUML' or\
            row[54]  == 'Michigan State University' or\
            row[54] == 'University of Minnesota' or\
            row[100] == 'Queensland Museum' or\
            row[100] == 'something':
            pass
        
        # Colorado
        elif row[100]== 'Colorado Plateau Museum of Arthropod Biodiversity (NAUF-CPMAB)' and '_F.' in row[15]:
            cleaned_list.append(row)    
        elif row[100]== 'Colorado Plateau Museum of Arthropod Biodiversity (NAUF-CPMAB)':
            pass
        
        
        # HARVARD
        elif 'Harvard University' in row[100] and '_hef' in row[5]:
            cleaned_list.append(row)    
        elif row[100]== 'Museum of Comparative Zoology, Harvard University':
            pass
        
        
        # also to exclude fossils, audio media, slides, drawers, broken links, no access
        elif 'PALE' in row[5] or \
            'macaulay' in row[15] or\
            'flickr' in row[5] or\
            'invert' in row[5] or\
            'utexas' in row[5] or\
            'osuc' in row[5] or\
            'yale' in row[5]: 
            pass
        
        
        # get rid the images which are reported as not dorsal view    
        elif 'Later' in row[29] or\
            'Dors' in row[29] or\
            'Tho' in row[30] or 'Gen' in row[30] or 'Whol' in row[30] or 'Ventr' in row[29]:
            pass   
        
        elif 'Head' in row[30]:
            cleaned_list.append(row)
        
        # how many images are not treated
        else:   
            remained.append(row)
            

print 'true\t\t' , len(cleaned_list)
print 'cleaned\t\t', total_media- len(cleaned_list)- len(remained)
print
print 'remained to treat\t', len(remained)
print 'total data\t\t', total_media
print
# Out:
# true		1227
# cleaned		43082
#
# remained to treat	323
# total data		44632

# %% [markdown]
# #### next, we checked institutions which we still have to treat

# %%
to_treat={}
for row in remained:
    if row[100] in to_treat.keys():
        to_treat[row[100]]+=1
    else:
        to_treat[row[100]]=1
for key in to_treat:
    print to_treat[key], key, '\n'
# Out:
# 305
#
# 1 Torsten Dikow
#
# 1 D.A. Grimaldi
#
# 1 xmpRights:Owner
#
# 2 Denver Museum of Nature & Science
#
# 2 Natural History Museum of Utah
#
# 1 Museum of Texas Tech University
#
# 8 T. Dikow
#
# 2 Arizona State University Hasbrouck Insect Collection (ASU-ASUHIC)

# %% [markdown]
# #### NOT IN USE

# %%
#the cell bellow is used to show links for untreated images provided by certain institution
num = 0
for row in remained:
    if 'arctos' in row[5]:
        num+=1
        print row[5]
print num
# Out:
# http://arctos.database.museum/media/10242599?open
# http://arctos.database.museum/media/10242602?open
# http://arctos.database.museum/media/10295393?open
# http://arctos.database.museum/media/10295394?open
# http://arctos.database.museum/media/10295395?open
# http://arctos.database.museum/media/10295396?open
# http://arctos.database.museum/media/10295561?open
# http://arctos.database.museum/media/10295562?open
# http://arctos.database.museum/media/10295563?open
# http://arctos.database.museum/media/10295564?open
# http://arctos.database.museum/media/10295568?open
# http://arctos.database.museum/media/10295569?open
# http://arctos.database.museum/media/10295570?open
# http://arctos.database.museum/media/10436823?open
# http://arctos.database.museum/media/10436996?open
# http://arctos.database.museum/media/10437005?open
# http://arctos.database.museum/media/10437053?open
# http://arctos.database.museum/media/10437144?open
# http://arctos.database.museum/media/10332175?open
# http://arctos.database.museum/media/10346885?open
# http://arctos.database.museum/media/10242609?open
# http://arctos.database.museum/media/10436800?open
# http://arctos.database.museum/media/10436824?open
# http://arctos.database.museum/media/10436827?open
# http://arctos.database.museum/media/10436843?open
# http://arctos.database.museum/media/10436746?open
# http://arctos.database.museum/media/10437041?open
# http://arctos.database.museum/media/10437051?open
# http://arctos.database.museum/media/10437067?open
# http://arctos.database.museum/media/10437077?open
# http://arctos.database.museum/media/10436910?open
# http://arctos.database.museum/media/10436915?open
# http://arctos.database.museum/media/10436961?open
# http://arctos.database.museum/media/10436826?open
# http://arctos.database.museum/media/10436840?open
# http://arctos.database.museum/media/10436977?open
# http://arctos.database.museum/media/10437046?open
# http://arctos.database.museum/media/10436904?open
# http://arctos.database.museum/media/10436922?open
# http://arctos.database.museum/media/10436948?open
# http://arctos.database.museum/media/10486034?open
# http://arctos.database.museum/media/10295525?open
# http://arctos.database.museum/media/10295526?open
# http://arctos.database.museum/media/10295527?open
# http://arctos.database.museum/media/10295528?open
# http://arctos.database.museum/media/10295529?open
# http://arctos.database.museum/media/10436775?open
# http://arctos.database.museum/media/10436793?open
# http://arctos.database.museum/media/10436974?open
# http://arctos.database.museum/media/10437047?open
# http://arctos.database.museum/media/10437063?open
# http://arctos.database.museum/media/10437151?open
# http://arctos.database.museum/media/10436876?open
# http://arctos.database.museum/media/10436918?open
# http://arctos.database.museum/media/10485203?open
# http://arctos.database.museum/media/10485204?open
# http://arctos.database.museum/media/10295534?open
# http://arctos.database.museum/media/10436631?open
# http://arctos.database.museum/media/10436809?open
# http://arctos.database.museum/media/10436831?open
# http://arctos.database.museum/media/10436838?open
# http://arctos.database.museum/media/10436965?open
# http://arctos.database.museum/media/10436973?open
# http://arctos.database.museum/media/10436975?open
# http://arctos.database.museum/media/10437002?open
# http://arctos.database.museum/media/10437010?open
# http://arctos.database.museum/media/10437059?open
# http://arctos.database.museum/media/10436921?open
# http://arctos.database.museum/media/10436829?open
# http://arctos.database.museum/media/10437003?open
# http://arctos.database.museum/media/10437035?open
# http://arctos.database.museum/media/10437048?open
# http://arctos.database.museum/media/10437084?open
# http://arctos.database.museum/media/10437150?open
# http://arctos.database.museum/media/10436903?open
# http://arctos.database.museum/media/10436947?open
# http://arctos.database.museum/media/10332179?open
# http://arctos.database.museum/media/10346889?open
# http://arctos.database.museum/media/10436661?open
# http://arctos.database.museum/media/10436799?open
# http://arctos.database.museum/media/10436805?open
# http://arctos.database.museum/media/10436808?open
# http://arctos.database.museum/media/10436815?open
# http://arctos.database.museum/media/10436833?open
# http://arctos.database.museum/media/10437007?open
# http://arctos.database.museum/media/10437061?open
# http://arctos.database.museum/media/10437066?open
# http://arctos.database.museum/media/10437147?open
# http://arctos.database.museum/media/10436909?open
# http://arctos.database.museum/media/10436945?open
# http://arctos.database.museum/media/10436962?open
# http://arctos.database.museum/media/10242622?open
# http://arctos.database.museum/media/10436786?open
# http://arctos.database.museum/media/10436830?open
# http://arctos.database.museum/media/10436841?open
# http://arctos.database.museum/media/10437012?open
# http://arctos.database.museum/media/10437039?open
# http://arctos.database.museum/media/10437040?open
# http://arctos.database.museum/media/10437045?open
# http://arctos.database.museum/media/10437060?open
# http://arctos.database.museum/media/10437152?open
# http://arctos.database.museum/media/10436905?open
# http://arctos.database.museum/media/10436913?open
# http://arctos.database.museum/media/10295666?open
# http://arctos.database.museum/media/10295533?open
# http://arctos.database.museum/media/10295535?open
# http://arctos.database.museum/media/10295536?open
# http://arctos.database.museum/media/10436834?open
# http://arctos.database.museum/media/10436970?open
# http://arctos.database.museum/media/10436984?open
# http://arctos.database.museum/media/10436997?open
# http://arctos.database.museum/media/10437008?open
# http://arctos.database.museum/media/10437015?open
# http://arctos.database.museum/media/10437064?open
# http://arctos.database.museum/media/10437078?open
# http://arctos.database.museum/media/10437079?open
# http://arctos.database.museum/media/10437145?open
# http://arctos.database.museum/media/10437149?open
# http://arctos.database.museum/media/10436907?open
# http://arctos.database.museum/media/10436912?open
# http://arctos.database.museum/media/10436936?open
# http://arctos.database.museum/media/10332586?open
# http://arctos.database.museum/media/10347585?open
# http://arctos.database.museum/media/10242574?open
# http://arctos.database.museum/media/10295718?open
# http://arctos.database.museum/media/10295719?open
# http://arctos.database.museum/media/10436792?open
# http://arctos.database.museum/media/10436795?open
# http://arctos.database.museum/media/10436836?open
# http://arctos.database.museum/media/10436982?open
# http://arctos.database.museum/media/10437011?open
# http://arctos.database.museum/media/10437043?open
# http://arctos.database.museum/media/10437155?open
# http://arctos.database.museum/media/10436917?open
# http://arctos.database.museum/media/10436963?open
# http://arctos.database.museum/media/10332176?open
# http://arctos.database.museum/media/10332180?open
# http://arctos.database.museum/media/10332595?open
# http://arctos.database.museum/media/10346886?open
# http://arctos.database.museum/media/10346890?open
# http://arctos.database.museum/media/10347594?open
# http://arctos.database.museum/media/10399513?open
# http://arctos.database.museum/media/10399514?open
# http://arctos.database.museum/media/10436807?open
# http://arctos.database.museum/media/10436844?open
# http://arctos.database.museum/media/10436764?open
# http://arctos.database.museum/media/10436972?open
# http://arctos.database.museum/media/10436981?open
# http://arctos.database.museum/media/10436985?open
# http://arctos.database.museum/media/10437044?open
# http://arctos.database.museum/media/10437081?open
# http://arctos.database.museum/media/10437146?open
# http://arctos.database.museum/media/10436911?open
# http://arctos.database.museum/media/10436960?open
# http://arctos.database.museum/media/10332183?open
# http://arctos.database.museum/media/10332596?open
# http://arctos.database.museum/media/10346893?open
# http://arctos.database.museum/media/10347595?open
# http://arctos.database.museum/media/10467902?open
# http://arctos.database.museum/media/10458113?open
# http://arctos.database.museum/media/10436629?open
# http://arctos.database.museum/media/10436811?open
# http://arctos.database.museum/media/10436814?open
# http://arctos.database.museum/media/10436825?open
# http://arctos.database.museum/media/10436842?open
# http://arctos.database.museum/media/10436967?open
# http://arctos.database.museum/media/10436968?open
# http://arctos.database.museum/media/10436999?open
# http://arctos.database.museum/media/10437013?open
# http://arctos.database.museum/media/10437038?open
# http://arctos.database.museum/media/10437057?open
# http://arctos.database.museum/media/10437062?open
# http://arctos.database.museum/media/10436902?open
# http://arctos.database.museum/media/10436944?open
# http://arctos.database.museum/media/10436946?open
# http://arctos.database.museum/media/10332588?open
# http://arctos.database.museum/media/10347587?open
# http://arctos.database.museum/media/10242627?open
# http://arctos.database.museum/media/10242660?open
# http://arctos.database.museum/media/10436813?open
# http://arctos.database.museum/media/10436819?open
# http://arctos.database.museum/media/10436821?open
# http://arctos.database.museum/media/10436998?open
# http://arctos.database.museum/media/10437014?open
# http://arctos.database.museum/media/10437082?open
# http://arctos.database.museum/media/10437148?open
# http://arctos.database.museum/media/10436949?open
# http://arctos.database.museum/media/10382931?open
# http://arctos.database.museum/media/10375116?open
# http://arctos.database.museum/media/10388602?open
# http://arctos.database.museum/media/10242579?open
# http://arctos.database.museum/media/10436780?open
# http://arctos.database.museum/media/10436784?open
# http://arctos.database.museum/media/10436828?open
# http://arctos.database.museum/media/10436832?open
# http://arctos.database.museum/media/10436978?open
# http://arctos.database.museum/media/10436979?open
# http://arctos.database.museum/media/10437017?open
# http://arctos.database.museum/media/10437018?open
# http://arctos.database.museum/media/10436908?open
# http://arctos.database.museum/media/10436920?open
# http://arctos.database.museum/media/10332592?open
# http://arctos.database.museum/media/10332593?open
# http://arctos.database.museum/media/10332594?open
# http://arctos.database.museum/media/10347591?open
# http://arctos.database.museum/media/10347592?open
# http://arctos.database.museum/media/10347593?open
# http://arctos.database.museum/media/10332589?open
# http://arctos.database.museum/media/10347588?open
# http://arctos.database.museum/media/10436630?open
# http://arctos.database.museum/media/10436837?open
# http://arctos.database.museum/media/10436969?open
# http://arctos.database.museum/media/10437000?open
# http://arctos.database.museum/media/10437006?open
# http://arctos.database.museum/media/10437037?open
# http://arctos.database.museum/media/10437050?open
# http://arctos.database.museum/media/10436906?open
# http://arctos.database.museum/media/10436916?open
# http://arctos.database.museum/media/10332181?open
# http://arctos.database.museum/media/10346891?open
# http://arctos.database.museum/media/10382930?open
# http://arctos.database.museum/media/10375115?open
# http://arctos.database.museum/media/10388601?open
# http://arctos.database.museum/media/10242720?open
# http://arctos.database.museum/media/10242636?open
# http://arctos.database.museum/media/10257297?open
# http://arctos.database.museum/media/10436660?open
# http://arctos.database.museum/media/10436779?open
# http://arctos.database.museum/media/10436798?open
# http://arctos.database.museum/media/10436818?open
# http://arctos.database.museum/media/10436820?open
# http://arctos.database.museum/media/10436835?open
# http://arctos.database.museum/media/10436839?open
# http://arctos.database.museum/media/10436966?open
# http://arctos.database.museum/media/10436983?open
# http://arctos.database.museum/media/10437009?open
# http://arctos.database.museum/media/10437052?open
# http://arctos.database.museum/media/10437065?open
# http://arctos.database.museum/media/10437072?open
# http://arctos.database.museum/media/10437080?open
# http://arctos.database.museum/media/10437157?open
# http://arctos.database.museum/media/10436914?open
# http://arctos.database.museum/media/10332182?open
# http://arctos.database.museum/media/10346892?open
# http://arctos.database.museum/media/10436812?open
# http://arctos.database.museum/media/10436822?open
# http://arctos.database.museum/media/10436976?open
# http://arctos.database.museum/media/10437001?open
# http://arctos.database.museum/media/10437016?open
# http://arctos.database.museum/media/10436959?open
# http://arctos.database.museum/media/10442744?open
# http://arctos.database.museum/media/10332174?open
# http://arctos.database.museum/media/10332177?open
# http://arctos.database.museum/media/10332591?open
# http://arctos.database.museum/media/10346884?open
# http://arctos.database.museum/media/10346887?open
# http://arctos.database.museum/media/10347590?open
# http://arctos.database.museum/media/10332585?open
# http://arctos.database.museum/media/10347584?open
# http://arctos.database.museum/media/10242650?open
# http://arctos.database.museum/media/10295530?open
# http://arctos.database.museum/media/10295531?open
# http://arctos.database.museum/media/10295532?open
# http://arctos.database.museum/media/10436777?open
# http://arctos.database.museum/media/10436796?open
# http://arctos.database.museum/media/10436971?open
# http://arctos.database.museum/media/10437049?open
# http://arctos.database.museum/media/10485205?open
# http://arctos.database.museum/media/10295704?open
# http://arctos.database.museum/media/10295706?open
# http://arctos.database.museum/media/10295707?open
# http://arctos.database.museum/media/10295708?open
# http://arctos.database.museum/media/10295709?open
# http://arctos.database.museum/media/10295710?open
# http://arctos.database.museum/media/10295711?open
# http://arctos.database.museum/media/10295712?open
# http://arctos.database.museum/media/10295713?open
# http://arctos.database.museum/media/10436794?open
# http://arctos.database.museum/media/10436810?open
# http://arctos.database.museum/media/10436980?open
# http://arctos.database.museum/media/10437004?open
# http://arctos.database.museum/media/10437042?open
# http://arctos.database.museum/media/10437058?open
# http://arctos.database.museum/media/10437083?open
# http://arctos.database.museum/media/10437156?open
# http://arctos.database.museum/media/10436873?open
# http://arctos.database.museum/media/10436964?open
# http://arctos.database.museum/media/10332178?open
# http://arctos.database.museum/media/10346888?open
# http://arctos.database.museum/media/10295565?open
# http://arctos.database.museum/media/10295566?open
# http://arctos.database.museum/media/10295567?open
# http://arctos.database.museum/media/10295667?open
# http://arctos.database.museum/media/10295513?open
# http://arctos.database.museum/media/10373154?open
# http://arctos.database.museum/media/10436995?open
# http://arctos.database.museum/media/10436874?open
# http://arctos.database.museum/media/10436919?open
# http://arctos.database.museum/media/10485941?open
# http://arctos.database.museum/media/10332587?open
# http://arctos.database.museum/media/10332590?open
# http://arctos.database.museum/media/10347586?open
# http://arctos.database.museum/media/10347589?open
# 303

# %% [markdown]
# ### save the list as csv file and add the titles in the first row

# %%
cleaned_list.insert(0, first_row)

with open('metadata/cleaned_head.csv', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    for row in range(len(cleaned_list)):
        wr.writerow(cleaned_list[row])

# %%
remained.insert(0, first_row)
with open('metadata/remained.csv', 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    for row in range(len(remained)):
        wr.writerow(remained[row])

# %% [markdown]
# # download the images
# from **cleaned_head.csv** and if you wish add manually more examples  from **remained.csv** for families with fewer examples

# %%
def download_all(records, dictionary, save_to, tax_level = 'family', num=25):
    if tax_level == 'genus':
        level = 4
    else:
        level = 3
    for key in dictionary.keys():
        if len(dictionary[key])>num:
            print 
            print len(dictionary[key]), key
            print
            directory = save_to + '/' + key
            if not os.path.exists(directory):
                os.makedirs(directory)
            for value in dictionary[key]:
                for i in records:
                    if value == i[0]:
                        print i[level]
                        urllib.urlretrieve(i[1], directory+'/'+i[2]+".jpg")

# %%
with open('metadata/cleaned_head.csv', 'rb') as csv1:
    dorsal = csv.reader(csv1)
    records = []
    record = []
    for row in dorsal:
        fullname = row[85].replace(' ', '_')
        record = [row[0], row[5], fullname]
        records.append(record)
    records=records[1:]    

    coreIDs = []
    for i in records:
        coreIDs.append(i[0])

# %%
with open('metadata/occurrence_raw.csv', 'rb') as csv2:
    reader = csv.reader(csv2)
    family ={}
    genus = {}
    for row in reader:
        #append to records family and genus
        for i in records:
            if row[0] == i[0]:
                i.append(row[56])
                i.append(row[61])
                
                if row[56] in family.keys():
                    family[row[56]].append(row[0])
                    if row[61] in genus.keys():
                        genus[row[61]].append(row[0])

                    else:
                        genus[row[61]] = []
                        genus[row[61]].append(row[0])
                else:
                    family[row[56]] = []
                    family[row[56]].append(row[0])

# %%
download_all(records, family, 'family', num=25)
# Out:
# 164 Asilidae
#
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
# Asilidae
#
# 128 Empididae
#
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
# Empididae
#
# 166 Dolichopodidae
#
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
# Dolichopodidae
#
# 30 Mycetophilidae
#
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
# Mycetophilidae
#
# 26 Rhagionidae
#
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
# Rhagionidae
#
# 164 Syrphidae
#
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
# Syrphidae
#
# 27 Conopidae
#
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
# Conopidae
#
# 111 Bombyliidae
#
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# Bombyliidae
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-df9ac48e8007> in <module>()
# ----> 1 download_all(records, family, 'family', num=25)
#
# <ipython-input-10-0bd7ed71d99f> in download_all(records, dictionary, save_to, tax_level, num)
#      16                     if value == i[0]:
#      17                         print i[level]
# ---> 18                         urllib.urlretrieve(i[1], directory+'/'+i[2]+".jpg")
#
# /usr/lib/python2.7/urllib.pyc in urlretrieve(url, filename, reporthook, data, context)
#      96     else:
#      97         opener = _urlopener
# ---> 98     return opener.retrieve(url, filename, reporthook, data)
#      99 def urlcleanup():
#     100     if _urlopener:
#
# /usr/lib/python2.7/urllib.pyc in retrieve(self, url, filename, reporthook, data)
#     271                     reporthook(blocknum, bs, size)
#     272                 while 1:
# --> 273                     block = fp.read(bs)
#     274                     if block == "":
#     275                         break
#
# /usr/lib/python2.7/socket.pyc in read(self, size)
#     382                 # fragmentation issues on many platforms.
#     383                 try:
# --> 384                     data = self._sock.recv(left)
#     385                 except error, e:
#     386                     if e.args[0] == EINTR:
#
# /usr/lib/python2.7/ssl.pyc in recv(self, buflen, flags)
#     754                     "non-zero flags not allowed in calls to recv() on %s" %
#     755                     self.__class__)
# --> 756             return self.read(buflen)
#     757         else:
#     758             return self._sock.recv(buflen, flags)
#
# /usr/lib/python2.7/ssl.pyc in read(self, len, buffer)
#     641                 v = self._sslobj.read(len, buffer)
#     642             else:
# --> 643                 v = self._sslobj.read(len)
#     644             return v
#     645         except SSLError as x:
#
# KeyboardInterrupt:

# %% [markdown]
# # make sure you examine and clean your dataset manually
#
# ### or you can simply download filtered images a list we provided
#
#     D1_list_of_filtered_images.csv
